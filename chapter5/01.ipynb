# %%
a = 100
b = 100
a + b
# Out:
# 200

# %%
x = 1000
y = 1000
x + y
# Out:
# 2000

# %%
import pandas as pd
df = pd.DataFrame({'A': [1, 2, 3], 'B ': [4, 5, 6]})
df.head()
# Out:
#    A  B
# 0  1   4
# 1  2   5
# 2  3   6

# %%
df = pd.DataFrame([
    {"name": "Alice", "age": 30},
    {"name": "Bob", "age": 25}, 
    {"name": "Charlie", "age": 35}
])

df['age'].max(),df['age'].min(), df['age'].mean()
# Out:
# (np.int64(35), np.int64(25), np.float64(30.0))

# %%
# Out:
# pandas installed successfully
